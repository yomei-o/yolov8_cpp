# %% [markdown]
# # Phase 3b — device-resident BatchNorm2d parity
# **Runtime → GPU**, Run all. Both: same L/checksums + `grad-check OK`.

# %%
# %cd /content
# !rm -rf yolov8_cpp
# !git clone -q --branch main https://github.com/yomei-o/yolov8_cpp.git
# %cd /content/yolov8_cpp

# %% [markdown]
# ### GPU

# %%
# !nvcc -x cu -O2 -std=c++17 --extended-lambda -arch=native -DUSE_CUDA pure/dbn_test.cpp -o dbn_gpu
# !./dbn_gpu; echo "exit=$?"

# %% [markdown]
# ### CPU

# %%
# !g++ -O2 -std=c++17 -I/usr/local/cuda/include -I/usr/local/cuda/include/cccl -DTHRUST_DEVICE_SYSTEM=THRUST_DEVICE_SYSTEM_CPP pure/dbn_test.cpp -o dbn_cpu
# !./dbn_cpu; echo "exit=$?"

# %% [markdown]
# **Expected** (local CPU): L=28.786341, dGamma=38.092561 dBeta=47.095860, grad-check OK.
