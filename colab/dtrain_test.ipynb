# %% [markdown]
# # Phase 5 — device-resident training step (forward+backward+Adam)
# **Runtime → GPU**, Run all. Loss must decrease -> `TRAIN OK` on both.

# %%
# %cd /content
# !rm -rf yolov8_cpp
# !git clone -q --branch main https://github.com/yomei-o/yolov8_cpp.git
# %cd /content/yolov8_cpp

# %% [markdown]
# ### GPU

# %%
# !nvcc -x cu -O2 -std=c++17 --extended-lambda -arch=native -DUSE_CUDA pure/dtrain_test.cpp -o dtrain_gpu
# !./dtrain_gpu; echo "exit=$?"

# %% [markdown]
# ### CPU

# %%
# !g++ -O2 -std=c++17 -I/usr/local/cuda/include -I/usr/local/cuda/include/cccl -DTHRUST_DEVICE_SYSTEM=THRUST_DEVICE_SYSTEM_CPP pure/dtrain_test.cpp -o dtrain_cpu
# !./dtrain_cpu; echo "exit=$?"

# %% [markdown]
# **Expected**: loss ~4.47 -> ~0.04, `TRAIN OK` on both. Full forward->backward->Adam runs device-resident.
