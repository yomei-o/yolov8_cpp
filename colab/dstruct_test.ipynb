# %% [markdown]
# # Phase 3 — device-resident structural ops parity
# maxpool / upsample2x / slice / concat in `pure/dtensor.hpp`.
# **Runtime → GPU (T4)**, Run all. Both must print same L/checksum + `grad-check OK`.

# %%
# !nvidia-smi -L
# !nvcc --version | tail -1

# %%
# %cd /content
# !rm -rf yolov8_cpp
# !git clone -q --branch main https://github.com/yomei-o/yolov8_cpp.git
# %cd /content/yolov8_cpp

# %% [markdown]
# ### GPU

# %%
# !nvcc -x cu -O2 -std=c++17 --extended-lambda -arch=native -DUSE_CUDA pure/dstruct_test.cpp -o dstruct_gpu
# !./dstruct_gpu; echo "exit=$?"

# %% [markdown]
# ### CPU (same source)

# %%
# !g++ -O2 -std=c++17 -I/usr/local/cuda/include -I/usr/local/cuda/include/cccl \
     -DTHRUST_DEVICE_SYSTEM=THRUST_DEVICE_SYSTEM_CPP pure/dstruct_test.cpp -o dstruct_cpu
# !./dstruct_cpu; echo "exit=$?"

# %% [markdown]
# ---
# **Expected** (matches local CPU): `L = 134.519379`, `sum(dL/dX) = 111.390143`, `grad-check OK` on both.
