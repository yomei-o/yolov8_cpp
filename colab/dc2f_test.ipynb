# %% [markdown]
# # Phase 4 — device-resident C2f block parity
# **Runtime → GPU**, Run all. Both: same L/checksum + `grad-check OK`.

# %%
# %cd /content
# !rm -rf yolov8_cpp
# !git clone -q --branch main https://github.com/yomei-o/yolov8_cpp.git
# %cd /content/yolov8_cpp

# %% [markdown]
# ### GPU

# %%
# !nvcc -x cu -O2 -std=c++17 --extended-lambda -arch=native -DUSE_CUDA pure/dc2f_test.cpp -o dc2f_gpu
# !./dc2f_gpu; echo "exit=$?"

# %% [markdown]
# ### CPU

# %%
# !g++ -O2 -std=c++17 -I/usr/local/cuda/include -I/usr/local/cuda/include/cccl -DTHRUST_DEVICE_SYSTEM=THRUST_DEVICE_SYSTEM_CPP pure/dc2f_test.cpp -o dc2f_cpu
# !./dc2f_cpu; echo "exit=$?"

# %% [markdown]
# **Expected** (local CPU): L=93.505257, sum(dL/dX)=~0, grad-check OK on both.
